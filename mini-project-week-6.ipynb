# %% [markdown]
# # mini project week 6 ! 🤩🤩💙

# %%
"""
Day 30 Activity: EDA Exercise
Tasks:
1) Load dataset
2) Run univariate, bivariate, and correlation analysis
3) Write 3 insights
"""

# TODO: Load data from data/day30_eda.csv
# TODO: Perform basic EDA and write insights

df_EDA = pd.read_csv("/kaggle/input/datasets/dana3333/day-30/day30_eda (1).csv")

# %% [markdown]
# # import for all data :🗝️

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 💙first step :
# # Understanding the data !🤩****

# %%
print("check info:")
df_EDA.info()

print("\ncheck first 5 rows:")
print(df_EDA.head())

print("\ncheck the details:")
print(df_EDA.describe())

print("\ncheck if we have any missing and their sum ⁉️:")
print(df_EDA.isna().sum())

print("\ncheck the shape:")
print(df_EDA.shape)

print("\ncheck types:")
print(df_EDA.dtypes)

"""cheek Numeric Columns + Categorical Columns"""

numeric_cols = df_EDA.select_dtypes(include="number").columns
cat_cols = df_EDA.select_dtypes(include="object").columns
print("Numeric Columns:", numeric_cols)
print("Categorical Columns:", cat_cols)


"""very important step !!, target Columns """

target = "segment"
print("Target column:", target)
print("Missing in target:", df_EDA[target].isna().sum())
# Out:
# check info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      4 non-null      int64
#  1   income   4 non-null      int64
#  2   spend    4 non-null      int64
#  3   segment  4 non-null      object
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes
#
# check first 5 rows:
#    age  income  spend segment
# 0   25   50000   2000       A
# 1   40   80000   4000       B
# 2   35   65000   3500       A
# 3   50  120000   6000       C
#
# check the details:
#             age         income        spend
# count   4.00000       4.000000     4.000000
# mean   37.50000   78750.000000  3875.000000
# std    10.40833   30103.986447  1652.018967
# min    25.00000   50000.000000  2000.000000
# 25%    32.50000   61250.000000  3125.000000
# 50%    37.50000   72500.000000  3750.000000
# 75%    42.50000   90000.000000  4500.000000
# ...

# %% [markdown]
# # 💙💙second step:
# # Histogram + KDE + Boxplot

# %%
numeric_cols = ["age", "income", "spend"]

for col in numeric_cols:
    plt.figure(figsize=(6,8))
    sns.histplot(df_EDA[col], bins=30, edgecolor="red", kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# # 🎨:Boxplot

# %%
for col in numeric_cols:
    plt.figure()
    sns.boxplot(x=ddf_EDAf[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# # 💙💙💙 step 3:
# # Distribution Insights💡

# %% [markdown]
# - Age: looks normal and balanced.
#
# - Income: has a small right skew because of higher values.
#
# - Spend: looks balanced with no big issues.

# %% [markdown]
# # 💙💙💙💙 step 4:
# # Boxplot by Segment

# %%
group_summary = df_EDA.groupby("segment")[["age","income","spend"]].agg(["mean","median","std","count"])
print(group_summary)

df_EDA.groupby("segment")[["age", "income", "spend"]].mean()
sns.boxplot(x="segment", y="age", data=df_EDA)
plt.title("Age by Segment")
plt.show()

sns.boxplot(x="segment", y="income", data=df_EDA)
plt.title("Income by Segment")
plt.show()

sns.boxplot(x="segment", y="spend", data=df_EDA)
plt.title("Spend by Segment")
plt.show()
# Out:
#           age                           income                                \
#          mean median       std count      mean    median           std count
# segment
# A        30.0   30.0  7.071068     2   57500.0   57500.0  10606.601718     2
# B        40.0   40.0       NaN     1   80000.0   80000.0           NaN     1
# C        50.0   50.0       NaN     1  120000.0  120000.0           NaN     1
#
#           spend
#            mean  median          std count
# segment
# A        2750.0  2750.0  1060.660172     2
# B        4000.0  4000.0          NaN     1
# C        6000.0  6000.0          NaN     1

# %% [markdown]
#  # Segment Comparison:💡💡
#
# - Segment C has the highest age, income, and spend.
# - Segment B is in the middle.
# - Segment A has the lowest values.

# %% [markdown]
# # 💙💙💙💙💙  step 5:
# # Correlation

# %%
df_EDA[["age", "income", "spend"]].corr()

sns.heatmap(df_EDA[["age", "income", "spend"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Correlation Insights💡💡💡
#
# - Age is strongly related to income and spend.
# - Income and spend are also strongly related.
# - As age increases, income and spend also increase.

# %% [markdown]
# 💙💙💙💙💙💙

# %% [markdown]
# # The last step !!!
# # Final Summary☑️⏳

# %% [markdown]
# - Most values are balanced and look normal.
#
# - Segment C has higher age, income, and spend.
#
# - Segment A has lower values.
#
# - Income and spend increase with age.
#
# - The features are strongly related to each other.

# %% [markdown]
# # 💙💙💙💙💙💙 💙
# # Recommended steps

# %% [markdown]
# # Recommended Next Steps💡💡💡💡
#
# - No strong outliers detected.
#
# - Income shows slight skew, may need scaling later.
#
# - Segment C behaves differently and could be modeled separately.
#
# - Features are highly correlated, so redundancy should be checked.
